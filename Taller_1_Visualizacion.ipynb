# %% [markdown]
# > ## TALLER 1: CRITICA VISUALIZACION DE DATOS
#
# >>>> Daniela A. Herrera Fandiño
#
# >>>>> Febrero 2022

# %% [markdown]
#  *1.PRIMERA VISUALIZACION*
#
#  > Medidas de protección contra el corona virus.

# %% [markdown]
# ![CoronavirusTransmissionGraphLN-superJumbo.png](data:image/png;base64,...)

# %% [markdown]
# Recuperado de : https://www.nytimes.com/2020/03/26/learning/whats-going-on-in-this-graph-coronavirus-protective-measures.html

# %% [markdown]
#    **¿QUÉ?**
#
# *  Data an Datasets Types: Networks and trees
# *  Dataset Availability: Static
#
# *   Attribute types: Orderer;Ordinal
# *   Ordering Direction: Sequential
#
#
#
# >   A partir de la visualizacion obtenida en la pagina del New York Times, se puede observar la disposicion que presentan frente a la pandemia registrada dado el COVID-19; de alli se prentende visulizar la propagacion de este. El diagrama de árbol presentado para este modelo estático, de manera ordenado ordinal en estudio permite visualizar el efecto trasmisión que se genera a partir de un primer contagio. Allí también es importante destacar la intención grafica que hay de por medio, respecto al distanciamiento social que debería presentarse.

# %% [markdown]
# **¿POR QUÉ?**
#
# *   Actions: Analyze;Present
#
#
# > La intención del análisis grafico que se  inferencia es principalmente presentar la importancia del distanciamiento para evitar significativamente la cantidad de personas infectadas.

# %% [markdown]
# **¿CÓMO?**
#
#
# *   Encode: Arrange:Express
# *   Manipulate: Change
# *   Facet: Partition
#
#
# > De otro modo, se esclarece de manera visual dos ramas graficas respecto al contagio, para presentar correctamente este análisis se propone una segunda y viable alternativa como seria la hipòtesis de evitar un primer caso positivo para lo cual se daría la mitigación de la propagación

# %% [markdown]
# **MARCAS Y CANALES**
#
#
# *   Marca: Lineas
#
# > *   Los canales que controlan la apariencia de esta marca es una posición combinada, ya que allí se muestra una cadena secuencial y de ampliación por cada persona contagiada
# *   El canal expresa identidad
# *Esta identidad del canal se clasifica en region espacial
# *Se percibe discriminalidad del canal

# %% [markdown]
# **REGLAS GENERALES**
#
#
#
#
# 1.   3D injustificado: no aplica
# 2.   3D justificado: no aplica
# 3. 2D injustificado
# >*    Se presenta la máxima cantidad de información presentada dentro de un formato 2D
# 4. Los ojos le ganan a la memoria
# >+ Es un grafico visual de fácil y rápida compresión asi tiene una carga cognitiva al espectador ya que permite ser de fácil recordación
# 5. Resolución sobre la inmersión: es una visualizacion clara
#
# * Al ser un grafico estatico no presenta dificultad para la percepción del ideal
# * Un diseño practico, y eficacaz para la capatacion de la idea central

# %% [markdown]
# **MEJORAS POSIBLES**
# * Concordancia entre titulo y grafico
# *Una de las ideas de esta visualización es presentar la importancia del distanciamiento social, para lo cual no es de fácil recepcion dentro de esta representación. Posiblemente un primer analisis referente respecto al contexto es la propagación

# %% [markdown]
# *2. SEGUNDA VISUALIZACION*
#
#
# > Accidentes eléctricos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Recuperado de : https://www.datos.gov.co/Minas-y-Energ-a/Accidentes-el-ctricos-a-os-2010-2020/4c8y-i7iw

# %% [markdown]
# **¿QUE?**
#
# > El resultado visual obtenido se da respecto a los accidentes eléctricos,defunciones,presentados en un periodo de tiempo 2010-2019 en los diferentes departamentos de Colombia.
#
# >Se emplea un grafico tipo geométrico el cual contiene valores categóricos cualitativos

# %% [markdown]
# **¿POR QUÉ**
#
#
# *   Actions: Analyze;Present
#
#
# > Se presenta esta información con el fin de dar a conocer los resultados catastróficos en cada periodo de tiempo, en donde se registra mayor cantidad de defunciones en el año 2018 representados en un 15%.

# %% [markdown]
# **¿CÓMO?**
#
#
# *   Map: Color;Hue
# *   Facet: Partition
#
#
#
# > Dada la información registrada se filtra por perido de tiempo, para este caso por años

# %% [markdown]
# **MARCAS Y CANALES**
# * La marca empleada para este contexto esta dada por áreas respecto a la cantidad de funciones en un año
# * Dado el grafico se genera a su vez una marca de angulo
# * Esta visualización presenta un canal de pisicIon angular y de color para diferenciar los periodos de tiempo

# %% [markdown]
# **REGLAS GENERALES**
#
#
# * Se evidencia una adecuada distribucion de los datos, para lo cual el grafico elegido es representativo para el concepto de estudio
# * La visualizacion estatica permite obtener enfasis dentro del estudio
